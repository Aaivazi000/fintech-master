# %% [markdown]
# # Python Notebook for Week 1
# ### Topic: Preliminary EDA of given data
# #### Basic Info:
#     Owner: Andriana Aivazians
#     Date: April 10th, 2018

# %% [markdown]
# ### Import Classes & Libraries

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Import Data Sets to Notebook

# %%
#Src is the 5 years of S&P 500 stock data given by Professor Auroa
src = pd.read_csv("/Users/andriana/Capstone_Data/all_stocks_5yr.csv")

# %%
#Getting a quick look
src.head()
# Out:
#          date   open   high    low  close    volume Name
# 0  2013-02-08  15.07  15.12  14.63  14.75   8407500  AAL
# 1  2013-02-11  14.89  15.01  14.26  14.46   8882000  AAL
# 2  2013-02-12  14.45  14.51  14.10  14.27   8126000  AAL
# 3  2013-02-13  14.30  14.94  14.25  14.66  10259500  AAL
# 4  2013-02-14  14.94  14.96  13.16  13.99  31879900  AAL

# %%
src.tail()
# Out:
#               date   open   high    low  close   volume Name
# 619035  2018-02-01  76.84  78.27  76.69  77.82  2982259  ZTS
# 619036  2018-02-02  77.53  78.12  76.73  76.78  2595187  ZTS
# 619037  2018-02-05  76.64  76.92  73.18  73.83  2962031  ZTS
# 619038  2018-02-06  72.74  74.56  72.13  73.27  4924323  ZTS
# 619039  2018-02-07  72.70  75.00  72.69  73.86  4534912  ZTS

# %%
#We can see there are 619039 rows and 8 features

# %%
open_5yrs = src['open']
open_5yrs.head()
# Out:
# 0    15.07
# 1    14.89
# 2    14.45
# 3    14.30
# 4    14.94
# Name: open, dtype: float64

# %%
close_5yrs = src['close']

# %%
low_5yrs = src['low']

# %%
high_5yrs = src['high']

# %%
fig1 = src.plot(x='date',y=['open','close','high','low'],subplots=True,figsize=(15,10))

# %%
fig1
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x10b79d2e8>,
# ...
#        <matplotlib.axes._subplots.AxesSubplot object at 0x10c3ce8d0>], dtype=object)

# %%
fig2= src.plot(x='date',y=['open'],figsize=(15,10))

# %%
fig2

# %%
#Basic Stats

# %%
open_5yrs.describe()
# Out:
# count    619029.000000
# mean         83.023334
# std          97.378769
# min           1.620000
# 25%          40.220000
# 50%          62.590000
# 75%          94.370000
# max        2044.000000
# Name: open, dtype: float64

# %%
close_5yrs.describe()
# Out:
# count    619040.000000
# mean         83.043763
# std          97.389748
# min           1.590000
# 25%          40.245000
# 50%          62.620000
# 75%          94.410000
# max        2049.000000
# Name: close, dtype: float64

# %%
low_5yrs.describe()
# Out:
# count    619032.000000
# mean         82.256096
# std          96.507421
# min           1.500000
# 25%          39.830000
# 50%          62.020000
# 75%          93.540000
# max        2035.110000
# Name: low, dtype: float64

# %%
high_5yrs.describe()
# Out:
# count    619032.000000
# mean         83.778311
# std          98.207519
# min           1.690000
# 25%          40.620000
# 50%          63.150000
# 75%          95.180000
# max        2067.990000
# Name: high, dtype: float64

# %%
table1 = src.groupby(by=['Name']).describe()

# %%
table1['open']
# Out:
#        count        mean        std       min       25%      50%       75%  \
# Name
# A     1259.0   49.187863   9.244798   33.1800   41.5150   46.640   56.4350
# AAL   1259.0   38.390495  10.967086   13.1400   34.2050   40.930   46.5650
# AAP   1259.0  132.439631  31.269628   76.0400  104.0700  141.150  156.9800
# AAPL  1259.0  109.055429  30.549220   55.4242   84.6478  108.970  127.3350
# ABBV  1259.0   60.802801  13.663931   35.0500   52.6800   60.040   65.7200
# ABC   1259.0   82.066430  16.333992   46.3800   70.5950   82.550   92.4950
# ABT   1259.0   42.924758   5.860552   33.0100   38.4800   42.290   45.7700
# ACN   1259.0  101.022826  22.105091   70.5800   80.6800   97.800  117.0200
# ADBE  1259.0   90.387609  36.964561   38.1400   65.9950   80.530  105.7950
# ADI   1259.0   60.928583  13.403447   42.2000   50.3200   56.910   67.9050
# ADM   1259.0   42.379519   5.209509   30.2200   39.2900   42.820   45.6500
# ...

# %%
table1['high'].head()
# Out:
#        count        mean        std      min        25%       50%       75%  \
# Name
# A     1259.0   49.600059   9.264168  34.0600   41.87000   47.0000   56.9350
# AAL   1259.0   38.955554  11.073650  13.4200   34.93000   41.4295   47.1875
# AAP   1259.0  133.818297  31.545809  76.6600  105.72495  143.0000  158.2700
# AAPL  1259.0  109.951118  30.686186  57.0857   85.33495  110.0300  128.1000
# ABBV  1259.0   61.474133  13.859815  35.5700   53.20000   60.8700   66.2350
#
#          max
# Name
# A      75.00
# AAL    59.08
# AAP   201.24
# AAPL  180.10
# ABBV  125.86

# %%
table1['low'].head()
# Out:
#        count        mean        std      min        25%       50%      75%  \
# Name
# A     1259.0   48.782026   9.197698  33.1150   41.26000   46.3410   56.025
# AAL   1259.0   37.825605  10.843652  12.7000   33.69000   40.2099   45.990
# AAP   1259.0  131.036025  30.968405  75.6230  102.26000  139.4050  155.320
# AAPL  1259.0  108.141589  30.376224  55.0142   84.25065  108.0500  126.290
# ABBV  1259.0   60.177275  13.551290  35.0100   52.03500   59.3900   65.205
#
#          max
# Name
# A      74.30
# AAL    57.80
# AAP   198.16
# AAPL  178.25
# ABBV  118.98

# %%
table1['volume'].head()
# Out:
#        count          mean           std         min         25%         50%  \
# Name
# A     1259.0  2.338039e+06  1.400161e+06    532863.0   1533017.5   2003109.0
# AAL   1259.0  9.390321e+06  6.899305e+06   1352400.0   5696393.0   8111323.0
# AAP   1259.0  1.078043e+06  1.019365e+06    130712.0    618201.0    849135.0
# AAPL  1259.0  5.404790e+07  3.346835e+07  11475922.0  29694376.5  45668931.0
# ABBV  1259.0  7.870683e+06  5.746644e+06   1747000.0   4877665.0   6707435.0
#
#              75%          max
# Name
# A      2718401.0   18146408.0
# AAL   11188535.0  137767165.0
# AAP    1219762.5   19749515.0
# AAPL  68708720.0  266833581.0
# ABBV   9309264.5  122740856.0

# %%
src.head()
# Out:
#          date   open   high    low  close    volume Name
# 0  2013-02-08  15.07  15.12  14.63  14.75   8407500  AAL
# 1  2013-02-11  14.89  15.01  14.26  14.46   8882000  AAL
# 2  2013-02-12  14.45  14.51  14.10  14.27   8126000  AAL
# 3  2013-02-13  14.30  14.94  14.25  14.66  10259500  AAL
# 4  2013-02-14  14.94  14.96  13.16  13.99  31879900  AAL
